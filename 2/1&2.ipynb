# %% [markdown]
# 1.Import the dataset and explore basic info (nulls, data types).

# %% [markdown]
# Import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Uploading the dataset

# %%
df = pd.read_csv('/content/Titanic-Dataset.csv')

# %% [markdown]
# basic info

# %%
print("Shape:", df.shape)
print("\nInfo:")
print(df.info())
print("\nMissing values per column:")
print(df.isnull().sum())
df.head()
# Out:
# Shape: (891, 12)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB
# None
#
# Missing values per column:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# ...

# %% [markdown]
# 2.Handle missing values

# %%
#for numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns
for col in num_cols:
    df[col].fillna(df[col].mean(), inplace=True)

#for categorical columns
cat_cols = df.select_dtypes(include=['object']).columns
for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)

#
df.isnull().sum()
# Out:
# /tmp/ipython-input-2995506338.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mean(), inplace=True)
# /tmp/ipython-input-2995506338.py:9: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# 3.Convert categorical features into numerical using encoding

# %%
#for categorical features
df_encoded = pd.get_dummies(df, drop_first=True)
print("Data after encoding:")
df_encoded.head()
# Out:
# Data after encoding:
#    PassengerId  Survived  Pclass   Age  SibSp  Parch     Fare  \
# 0            1         0       3  22.0      1      0   7.2500
# 1            2         1       1  38.0      1      0  71.2833
# 2            3         1       3  26.0      0      0   7.9250
# 3            4         1       1  35.0      1      0  53.1000
# 4            5         0       3  35.0      0      0   8.0500
#
#    Name_Abbott, Mr. Rossmore Edward  Name_Abbott, Mrs. Stanton (Rosa Hunt)  \
# 0                             False                                  False
# 1                             False                                  False
# 2                             False                                  False
# 3                             False                                  False
# 4                             False                                  False
#
#    Name_Abelson, Mr. Samuel  ...  Cabin_F G63  Cabin_F G73  Cabin_F2  \
# ...

# %% [markdown]
# 4.Normalize/standardize the numerical features

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

num_cols=df_encoded.select_dtypes(include=['int64', 'float64']).columns
df_encoded[num_cols]=scaler.fit_transform(df_encoded[num_cols])

print("Data after standardization: ")
df_encoded.head()
# Out:
# Data after standardization:
#    PassengerId  Survived    Pclass       Age     SibSp     Parch      Fare  \
# 0    -1.730108 -0.789272  0.827377 -0.592481  0.432793 -0.473674 -0.502445
# 1    -1.726220  1.266990 -1.566107  0.638789  0.432793 -0.473674  0.786845
# 2    -1.722332  1.266990  0.827377 -0.284663 -0.474545 -0.473674 -0.488854
# 3    -1.718444  1.266990 -1.566107  0.407926  0.432793 -0.473674  0.420730
# 4    -1.714556 -0.789272  0.827377  0.407926 -0.474545 -0.473674 -0.486337
#
#    Name_Abbott, Mr. Rossmore Edward  Name_Abbott, Mrs. Stanton (Rosa Hunt)  \
# 0                             False                                  False
# 1                             False                                  False
# 2                             False                                  False
# 3                             False                                  False
# 4                             False                                  False
#
# ...

# %% [markdown]
# 5.Visualize outliers using boxplots and remove them

# %%
# Boxplots
plt.figure(figsize=(15, 8))
df_encoded[num_cols].boxplot()
plt.title("Boxplots for Numerical Features (Before Outlier Removal)")
plt.show()

# Remove outliers
Q1 = df_encoded[num_cols].quantile(0.25)
Q3 = df_encoded[num_cols].quantile(0.75)
IQR = Q3 - Q1
df_no_outliers = df_encoded[~((df_encoded[num_cols] < (Q1 - 1.5 * IQR)) | (df_encoded[num_cols] > (Q3 + 1.5 * IQR))).any(axis=1)]

print("Shape before:", df_encoded.shape)
print("Shape after removing outliers:", df_no_outliers.shape)

# Visualize again
plt.figure(figsize=(15, 8))
df_no_outliers[num_cols].boxplot()
plt.title("Boxplots for Numerical Features (After Outlier Removal)")
plt.show()
# Out:
# Shape before: (891, 1726)
# Shape after removing outliers: (577, 1726)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # task 2

# %% [markdown]
# 1. Generate summary statistics

# %%
# Summary statistics
df_no_outliers.describe().T
# Out:
#              count      mean           std       min       25%       50%  \
# PassengerId  577.0  0.017849  1.009171e+00 -1.730108 -0.870886  0.034991
# Survived     577.0 -0.172750  9.429596e-01 -0.789272 -0.789272 -0.789272
# Pclass       577.0  0.232117  8.782992e-01 -1.566107 -0.369365  0.827377
# Age          577.0  0.003305  6.554200e-01 -1.900705 -0.438572  0.000000
# SibSp        577.0 -0.293706  4.037963e-01 -0.474545 -0.474545 -0.474545
# Parch        577.0 -0.473674  2.777966e-16 -0.473674 -0.473674 -0.473674
# Fare         577.0 -0.347884  2.538284e-01 -0.648422 -0.491874 -0.474005
#
#                   75%       max
# PassengerId  0.894213  1.730108
# Survived     1.266990  1.266990
# Pclass       0.827377  0.827377
# Age          0.215540  1.870059
# SibSp       -0.474545  1.340132
# Parch       -0.473674 -0.473674
# Fare        -0.329287  0.583318

# %% [markdown]
# 2. Create histograms and boxplots for numeric features

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numeric_cols = df_no_outliers.select_dtypes(include=['float64', 'int64']).columns

# Histograms
df_no_outliers[numeric_cols].hist(figsize=(15, 10))
plt.suptitle("Histograms of Numerical Features", fontsize=16)
plt.show()

# Boxplots
plt.figure(figsize=(15, 8))
df_no_outliers[numeric_cols].boxplot()
plt.title("Boxplots of Numerical Features")
plt.show()

# %% [markdown]
# 3. Pairplot and correlation matrix

# %%
# Pairplot (may take time depending on dataset size)
sns.pairplot(df_no_outliers[numeric_cols])
plt.show()

# Correlation matrix
plt.figure(figsize=(12, 8))
sns.heatmap(df_no_outliers[numeric_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# 4. Identify patterns, trends, and anomalies

# %%
# Check correlation strengths
corr = df_no_outliers[numeric_cols].corr()
corr
# Out:
#              PassengerId  Survived    Pclass       Age     SibSp  Parch  \
# PassengerId     1.000000 -0.050556 -0.054511  0.045852 -0.102197    NaN
# Survived       -0.050556  1.000000 -0.242189  0.006573  0.097999    NaN
# Pclass         -0.054511 -0.242189  1.000000 -0.354983 -0.078664    NaN
# Age             0.045852  0.006573 -0.354983  1.000000  0.024616    NaN
# SibSp          -0.102197  0.097999 -0.078664  0.024616  1.000000    NaN
# Parch                NaN       NaN       NaN       NaN       NaN    NaN
# Fare            0.019040  0.268890 -0.670942  0.261098  0.345588    NaN
#
#                  Fare
# PassengerId  0.019040
# Survived     0.268890
# Pclass      -0.670942
# Age          0.261098
# SibSp        0.345588
# Parch             NaN
# Fare         1.000000

# %% [markdown]
# 5. Make basic feature-level inferences from visuals

# %%
'''
1. Age

The age distribution is roughly bell-shaped, centered around young adults.
Very young ages (0–5) appear frequently.
Boxplot shows moderate outliers, mostly older passengers above age ~65.
No extreme skew.

2. Fare
Histogram shows a strong right skew: most passengers paid very low fares.
A long tail extends upward due to a small number of very expensive tickets.
Boxplot highlights multiple high-value outliers, indicating income/class inequality.
Suggests that fare may strongly correlate with travel class and survival.

3. Pclass
The distribution is highly imbalanced, with most passengers in 3rd class.
Boxplot shows no outliers.

4. SibSp
Histogram shows that most passengers traveled with 0 or 1 sibling/spouse.
Boxplot have few extreme outliers (values 5–8), representing large families.
Majority of values are clustered near 0.

5. Parch
Similar to SibSp: most passengers traveled without parents or children.
A few outliers (values 4–6) represent large family groups.
Distribution is extremely right-skewed.

6. Overall Outlier Pattern
Fare, SibSp, and Parch contain significant outliers.
Age contains mild outliers.
Pclass has no meaningful numeric outliers.
'''
